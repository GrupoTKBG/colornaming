# %%
import sys
sys.path.append('..')

# %%
import numpy as np
from PIL import Image
from colornaming import get_model
from colornaming.img import QImage

# %%
img_file = "D:/Users/isanz/Downloads/WhatsApp Image 2023-02-01 at 16.18.02.jpeg"
img = Image.open(img_file)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=380x340>

# %%
qimg = QImage(np.array(img), model=get_model("qcd"))
qimg.top_colors(5)
# Out:
# [('pale_blue', 0.1891795665634675),
#  ('light_grey', 0.17510061919504644),
#  ('grey', 0.17154024767801856),
#  ('white', 0.14506965944272446),
#  ('dark_orange', 0.09756191950464396)]

# %%
qimg = QImage(np.array(img), model=get_model("kobayashi"))
qimg.top_colors(5)
# Out:
# [('P/Dl', 0.1364938080495356),
#  ('N5', 0.09613777089783282),
#  ('PB/Vp', 0.06741486068111455),
#  ('Y/Dl', 0.06418730650154798),
#  ('N7', 0.04857585139318885)]

# %%
qimg.top_moods(5)
# Out:
# [('sober', 0.6642260061919505),
#  ('chic', 0.6611609907120742),
#  ('exact', 0.6348529411764706),
#  ('urbane', 0.6132352941176471),
#  ('quiet and sophisticated', 0.5525464396284829)]
